# %%
import pandas as pd
# !pip install openpyxl

# %%
# import the excel file
crowdfunding = pd.read_excel("./Starter_Files/Resources/crowdfunding.xlsx")
crowdfunding
# Out:
#      cf_id  contact_id                  company_name  \
# 0      147        4661    Baldwin, Riley and Jackson
# 1     1621        3765                      Odom Inc
# 2     1812        4187    Melton, Robinson and Fritz
# 3     2156        4941   Mcdonald, Gonzalez and Ross
# 4     1365        2199                 Larson-Little
# ..     ...         ...                           ...
# 995   2986        3684              Manning-Hamilton
# 996   2031        5784                    Butler LLC
# 997   1627        1498                      Ball LLC
# 998   2175        6073   Taylor, Santiago and Flores
# 999   1788        4939  Hernandez, Norton and Kelley
#
#                                              blurb    goal  pledged  \
# 0             Pre-emptive tertiary standardization     100        0
# 1                 Managed bottom-line architecture    1400    14560
# 2     Function-based leadingedge pricing structure  108400   142523
# ...

# %%
# get the unique category and create the dataframe
category = crowdfunding['category & sub-category'].str.split('/',expand=True)[0].unique()
categories_df= pd.DataFrame(category,columns=['category'])
categories_df
# Out:
#        category
# 0          food
# 1         music
# 2    technology
# 3       theater
# 4  film & video
# 5    publishing
# 6         games
# 7   photography
# 8    journalism

# %%
#add the category_id as consecutive
categories_df['category_id']=['cat{}'.format(i+1) for i, _ in enumerate(categories_df['category'])]
categories_df
# Out:
#        category category_id
# 0          food        cat1
# 1         music        cat2
# 2    technology        cat3
# 3       theater        cat4
# 4  film & video        cat5
# 5    publishing        cat6
# 6         games        cat7
# 7   photography        cat8
# 8    journalism        cat9

# %%
#reorder the columns in the dataframe

categories_df=categories_df[['category_id','category']]
categories_df
# Out:
#   category_id      category
# 0        cat1          food
# 1        cat2         music
# 2        cat3    technology
# 3        cat4       theater
# 4        cat5  film & video
# 5        cat6    publishing
# 6        cat7         games
# 7        cat8   photography
# 8        cat9    journalism

# %%
#export the data frame in a csv

categories_df.to_csv('category.csv',index=False)

# %%
# get the unique category and create the dataframe
category = crowdfunding['category & sub-category'].str.split('/',expand=True)[1].unique()
subcategories_df= pd.DataFrame(category,columns=['subcategory'])
subcategories_df
# Out:
#           subcategory
# 0         food trucks
# 1                rock
# 2                 web
# 3               plays
# 4         documentary
# 5      electric music
# 6               drama
# 7          indie rock
# 8           wearables
# 9          nonfiction
# 10          animation
# 11        video games
# 12             shorts
# 13            fiction
# 14  photography books
# 15   radio & podcasts
# 16              metal
# 17               jazz
# 18       translations
# 19         television
# 20       mobile games
# 21        world music
# 22    science fiction
# 23              audio

# %%
#add the category_id as consecutive
subcategories_df['subcategory_id']=['subcat{}'.format(i+1) for i, _ in enumerate(subcategories_df['subcategory'])]
subcategories_df
# Out:
#           subcategory subcategory_id
# 0         food trucks        subcat1
# 1                rock        subcat2
# 2                 web        subcat3
# 3               plays        subcat4
# 4         documentary        subcat5
# 5      electric music        subcat6
# 6               drama        subcat7
# 7          indie rock        subcat8
# 8           wearables        subcat9
# 9          nonfiction       subcat10
# 10          animation       subcat11
# 11        video games       subcat12
# 12             shorts       subcat13
# 13            fiction       subcat14
# 14  photography books       subcat15
# 15   radio & podcasts       subcat16
# 16              metal       subcat17
# 17               jazz       subcat18
# 18       translations       subcat19
# 19         television       subcat20
# 20       mobile games       subcat21
# 21        world music       subcat22
# 22    science fiction       subcat23
# 23              audio       subcat24

# %%
#reorder the columns in the dataframe

subcategories_df=subcategories_df[['subcategory_id','subcategory']]
subcategories_df
# Out:
#    subcategory_id        subcategory
# 0         subcat1        food trucks
# 1         subcat2               rock
# 2         subcat3                web
# 3         subcat4              plays
# 4         subcat5        documentary
# 5         subcat6     electric music
# 6         subcat7              drama
# 7         subcat8         indie rock
# 8         subcat9          wearables
# 9        subcat10         nonfiction
# 10       subcat11          animation
# 11       subcat12        video games
# 12       subcat13             shorts
# 13       subcat14            fiction
# 14       subcat15  photography books
# 15       subcat16   radio & podcasts
# 16       subcat17              metal
# 17       subcat18               jazz
# 18       subcat19       translations
# 19       subcat20         television
# 20       subcat21       mobile games
# 21       subcat22        world music
# 22       subcat23    science fiction
# 23       subcat24              audio

# %%
#export the data frame in a csv

subcategories_df.to_csv('subcategory.csv',index=False)
